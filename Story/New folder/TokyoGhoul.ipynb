# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets

# %%
test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# %%
import os as os
from PIL import Image
from scipy import misc
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
im = Image.open('./ironMaiden/000aa097d423_01.jpg')
pic = misc.imread('./ironMaiden/000aa097d423_01.jpg')
print(type(pic))
plt.imshow(pic)
Terragon = torch.tensor(pic)
print(Terragon[0])
# Out:
# <class 'numpy.ndarray'>
# tensor([[254, 250, 247],
#         [254, 250, 247],
#         [254, 250, 247],
#         ...,
#         [255, 251, 248],
#         [255, 251, 248],
#         [255, 251, 248]], dtype=torch.uint8)

# %%
for files in os.listdir('./ironMaiden'):
    im = Image.open('./ironMaiden/000aa097d423_01.JPG')
    trans = transforms.ToPILImage()
    trans1 = transforms.ToTensor()

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torchvision.datasets as dsets

# %%
class LogisticRegressionModel(nn.Module):
    def __init__(self,input_dim,output_dim):
        super(LogisticRegressionModel,self).__init__()
        self.linear = nn.Linear(input_dim,output_dim)
    def forward(self,x):
        out = self.linear(x)
        return out

# %%
input_dim = 28*28
output_dim = 10

model = LogisticRegressionModel(input_dim,output_dim)

train_dataset = dsets.MNIST(root='./data', 
                            train=True, 
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./data', 
                           train=False, 
                           transform=transforms.ToTensor())

# %%
print(type(model))
# Out:
# <class '__main__.LogisticRegressionModel'>

# %%
print(len(train_dataset))
# Out:
# 60000

# %%
batch_size = 100
n_iters = 3000
num_epochs = n_iters / (len(train_dataset) / batch_size)
num_epochs = int(num_epochs)

train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
class FeedforwardNeuralNetModel(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(FeedforwardNeuralNetModel, self).__init__()
        # Linear function
        self.fc1 = nn.Linear(input_dim, hidden_dim) 
        # Non-linearity
        self.sigmoid = nn.Sigmoid()
        # Linear function (readout)
        self.fc2 = nn.Linear(hidden_dim, output_dim)  
    
    def forward(self, x):
        # Linear function  # LINEAR
        out = self.fc1(x)
        # Non-linearity  # NON-LINEAR
        out = self.sigmoid(out)
        # Linear function (readout)  # LINEAR
        out = self.fc2(out)
        return out

# %%
inputDims = 28*28
hiddenDims = 100
outputDims = 10

model = FeedforwardNeuralNetModel(inputDims,hiddenDims,outputDims)

# %%
model
# Out:
# FeedforwardNeuralNetModel(
#   (fc1): Linear(in_features=784, out_features=100, bias=True)
#   (sigmoid): Sigmoid()
#   (fc2): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
criterion = nn.CrossEntropyLoss()

# %%
learning_rate = 0.1
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %%
for i, (images, labels) in enumerate(train_loader):
    print(type(labels[1]))
# Out:
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# <class 'torch.Tensor'>
# ...

# %%
import torchvision.transforms as transforms
import torch.utils.data as data
import torchvision

# %%
imagenet_data = torchvision.datasets.ImageFolder(root='./Matrix/',transform=transforms.Compose([transforms.ToTensor()]))

# %%
print(imagenet_data[0][1])
# Out:
# 0

# %%
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor

# %%
data = ImageFolder(root='./Matrix/', transform=ToTensor())

# %%
print(data.classes)
# Out:
# ['cars', 'images']

# %%
for i in data:
    print(i[1])
# Out:
# 0
# 0
# 0
# 0
# 1
# 1
# 1
# 1
# 1

# %%
o = 'cool_2'
try:  
    os.mkdir(o)
except OSError:  
    print ("Creation of the directory %s failed" % o)
else:  
    print ("Successfully created the directory %s " % o)
# Out:
# Creation of the directory cool_2 failed

# %%
cwd = os.getcwd()

# %%
print(cwd)
# Out:
# C:\Users\santo\Downloads\deep-learning-wizard-practical-pytorch-notebooks\deep_learning_wizard_practical_pytorch_notebooks

# %%
for files in os.listdir(cwd):
    print(files)
    if files=='cool1':
        print('hi')
# Out:
# .ipynb_checkpoints
# carvana-image-masking-challenge
# cool1
# hi
# cool2
# cool_2
# data
# images
# ironMaiden
# Matrix
# pytorch_convolutional_neuralnetwork.ipynb
# pytorch_feedforward_neuralnetwork.ipynb
# pytorch_gradients.ipynb
# pytorch_linear_regression.ipynb
# pytorch_logistic_regression.ipynb
# pytorch_lstm_neuralnetwork.ipynb
# pytorch_matrices.ipynb
# pytorch_recurrent_neuralnetwork.ipynb
# test
# test_hq
# TokyoGhoul.ipynb
# train
# Untitled.ipynb

# %%
os.rename(cwd+'\\train\\train\\0cdf5b5d0ce1_01.JPG', cwd+'\\train\\train\\yodawg.png')
#shutil.move("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-68-e6d300977e3e> in <module>()
# ----> 1 os.rename(cwd+'\\train\\train\\0cdf5b5d0ce1_01.JPG', cwd+'\\train\\train\\yodawg.png')
#       2 #shutil.move("path/to/current/file.foo", "path/to/new/destination/for/file.foo")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'C:\\Users\\santo\\Downloads\\deep-learning-wizard-practical-pytorch-notebooks\\deep_learning_wizard_practical_pytorch_notebooks\\train\\train\\0cdf5b5d0ce1_01.JPG' -> 'C:\\Users\\santo\\Downloads\\deep-learning-wizard-practical-pytorch-notebooks\\deep_learning_wizard_practical_pytorch_notebooks\\train\\train\\yodawg.png'

# %%
#Start for Input Database
import os as os
from PIL import Image
from scipy import misc
import matplotlib.pyplot as plt
import shutil

# %% [raw]
# temp = set()
# for files in os.listdir('./train/train/'):
#     t = files.split('_')
#     temp.add(str(t[0]))
#     print(t[0])

# %%
len(temp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-0433ca5d201c> in <module>()
# ----> 1 len(temp)
#
# NameError: name 'temp' is not defined

# %%
for i in temp:
    try:  
        os.mkdir('./train/'+i)
    except OSError:  
        print ("Creation of the directory %s failed" % o)
    else:  
        print ("Successfully created the directory %s " % o)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-2512265c39f6> in <module>()
# ----> 1 for i in temp:
#       2     try:
#       3         os.mkdir('./train/'+i)
#       4     except OSError:
#       5         print ("Creation of the directory %s failed" % o)
#
# NameError: name 'temp' is not defined

# %%
for files in os.listdir('./train/train/'):
    t = files.split('_')
    car = t[0]
    shutil.move('./train/train/' + files, './train/' + car)

# %%
imagenet_data = torchvision.datasets.ImageFolder(root='./train/',transform=transforms.Compose([transforms.ToTensor()]))

# %%
print(imagenet_data[0])
# Out:
# (tensor([[[0.9569, 0.9569, 0.9569,  ..., 0.9569, 0.9569, 0.9569],
#          [0.9569, 0.9569, 0.9569,  ..., 0.9569, 0.9569, 0.9569],
#          [0.9569, 0.9569, 0.9569,  ..., 0.9569, 0.9569, 0.9569],
#          ...,
#          [0.7020, 0.7020, 0.7020,  ..., 0.6902, 0.6902, 0.6902],
#          [0.7020, 0.7020, 0.7020,  ..., 0.6902, 0.6902, 0.6902],
#          [0.7020, 0.7020, 0.7020,  ..., 0.6902, 0.6902, 0.6902]],
#
#         [[0.9608, 0.9608, 0.9608,  ..., 0.9569, 0.9569, 0.9569],
#          [0.9608, 0.9608, 0.9608,  ..., 0.9569, 0.9569, 0.9569],
#          [0.9608, 0.9608, 0.9608,  ..., 0.9569, 0.9569, 0.9569],
#          ...,
#          [0.7176, 0.7176, 0.7176,  ..., 0.7059, 0.7059, 0.7059],
#          [0.7176, 0.7176, 0.7176,  ..., 0.7059, 0.7059, 0.7059],
#          [0.7176, 0.7176, 0.7176,  ..., 0.7059, 0.7059, 0.7059]],
#
#         [[0.9412, 0.9412, 0.9412,  ..., 0.9569, 0.9569, 0.9569],
#          [0.9412, 0.9412, 0.9412,  ..., 0.9569, 0.9569, 0.9569],
# ...

# %%
print(imagenet_data.classes)
# Out:
# ['00087a6bd4dc', '02159e548029', '03a857ce842d', '0495dcf27283', '04bd942b463b', '0789bed99cb8', '0795e132d090', '08a646be6b30', '0cdf5b5d0ce1', '0ce66b539f52', '0d1a9caf4350', '0d3adbbc9a8b', '0d53224da2b7', '0de66245f268', '0ed6904e1004', '0ee135a3cccc', '0eeaf1ff136d', '11acc40dc0ea', '11f3dc041cfb', '11fcda0a9e1c', '120c1dc7b116', '1258cf954183', '125cadcb9feb', '1390696b70b6', '13cad6eeabe8', '151c7f2d4183', '154ee2b6d27a', '169f5f6d8c9d', '16f0ec26d608', '189a2a32a615', '1952e5f91de0', '1a17a1bd648b', '1aba91a601c6', '1adaeb44f109', '1ae8a68a40e4', '1b25ea8ba94d', '1ba84b81628e', '1c5748340af8', '1e6f48393e17', '1e89e1af42e7', '21a7e6726ee3', '2267f4aa0d2c', '2335eef27de6', '23c088f6ec27', '245f9c9eab8a', '26ccab021981', '28109f18d9d4', '28d7fb5ba432', '28d9a149cb02', '292f59c6a347', '293a0fa72e5b', '2990f858e939', '2a4a8964ebf3', '2af7c265531e', '2c57132da7a0', '2cb06c1f5bb1', '2cb91c2543fa', '2ea62c1beee7', '2f39abb12388', '2faf504842df', '304437bad7ff', '3071362591f7', '3118
# ...

# %%
batch_size = 100

train_loader = torch.utils.data.DataLoader(dataset=imagenet_data, 
                                           batch_size=batch_size, 
                                           shuffle=True)

# %%
for i, (images, labels) in enumerate(train_loader):
    print(labels)
# Out:
# tensor([161, 121, 130, 303, 197, 203, 275, 206, 149, 310, 313, 169,  23, 176,
#         249, 296, 233, 120, 283,  96, 100, 162, 254, 236, 138,  92, 149, 145,
#          19, 231,  83, 101, 312, 138, 250, 116,  18, 293,  14, 286, 268,  66,
#         206, 190, 241, 252, 291, 106, 158,  52, 310,  77, 158,  61, 261,  68,
#         235, 170,  98, 100,  22,  40,  31,  20,  81, 199,  20, 187, 306, 113,
#          75, 253,  28, 166, 283, 312, 136, 307,  44, 200,  94, 222, 234, 202,
#         111, 199, 220, 253,  97, 185, 163,  74, 233, 289,  83, 124, 113, 156,
#         180, 223])
