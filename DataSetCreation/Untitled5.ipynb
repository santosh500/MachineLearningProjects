# %%
import numpy as np
import pandas as pd
import os as os
import cv2
import shutil

# %%
print('hi')
for files in os.listdir('./trainTrial1'):
    path = "./testTrialLand/" + files
    print('hi')
    try:  
        os.mkdir(path)
    except OSError:  
        print ("Creation of the directory %s failed" % path)
    else:  
        print ("Successfully created the directory %s " % path)
# Out:
# hi
# hi
# Successfully created the directory ./testTrialLand/0cdf5b5d0ce1
# hi
# Successfully created the directory ./testTrialLand/0ce66b539f52
# hi
# Successfully created the directory ./testTrialLand/0d1a9caf4350
# hi
# Successfully created the directory ./testTrialLand/0d3adbbc9a8b
# hi
# Successfully created the directory ./testTrialLand/0d53224da2b7
# hi
# Successfully created the directory ./testTrialLand/0de66245f268
# hi
# Successfully created the directory ./testTrialLand/0ed6904e1004
# hi
# Successfully created the directory ./testTrialLand/0ee135a3cccc
# hi
# Successfully created the directory ./testTrialLand/0eeaf1ff136d
# hi
# Successfully created the directory ./testTrialLand/1a17a1bd648b
# hi
# Successfully created the directory ./testTrialLand/1aba91a601c6
# hi
# Successfully created the directory ./testTrialLand/1adaeb44f109
# hi
# Successfully created the directory ./testTrialLand/1ae8a68a40e4
# hi
# Successfully created the directory ./testTrialLand/1b25ea8ba94d
# ...

# %%
#1 Create directories (both test and train)
for files in os.listdir('./trainTrial1'):
    path = "./testTrialLand/" + files
    print('hi')
    try:  
        os.mkdir(path)
    except OSError:  
        print ("Creation of the directory %s failed" % path)
    else:  
        print ("Successfully created the directory %s " % path)

# %%
#3 Move Files for test creation
for files in os.listdir('./trainMain'):
    print(files)
    for files2 in os.listdir('./trainMain/' + files):
        o = files2.split('_')
        q = o[1].split('.jpg')
        t = int(q[0])
        if((t%4)==0):
            if(t != 16):
                shutil.move('./trainMain/'+files+'/'+files2, './testMain/'+files+'/'+files2)
                print(t)
# Out:
# 00087a6bd4dc
# 4
# 8
# 12
# 02159e548029
# 4
# 8
# 12
# 03a857ce842d
# 4
# 8
# 12
# 0495dcf27283
# 4
# 8
# 12
# 04bd942b463b
# 4
# 8
# 12
# 0789bed99cb8
# 4
# 8
# 12
# 0795e132d090
# 4
# 8
# 12
# 08a646be6b30
# 4
# 8
# 12
# 0cdf5b5d0ce1
# 4
# 8
# 12
# 0ce66b539f52
# 4
# 8
# 12
# 0d1a9caf4350
# 4
# 8
# 12
# 0d3adbbc9a8b
# 4
# 8
# 12
# 0d53224da2b7
# 4
# 8
# 12
# 0de66245f268
# 4
# 8
# 12
# 0ed6904e1004
# 4
# 8
# 12
# 0ee135a3cccc
# 4
# 8
# 12
# 0eeaf1ff136d
# 4
# 8
# 12
# 11acc40dc0ea
# 4
# 8
# 12
# 11f3dc041cfb
# 4
# 8
# 12
# 11fcda0a9e1c
# 4
# 8
# 12
# 120c1dc7b116
# 4
# 8
# 12
# 1258cf954183
# 4
# 8
# 12
# 125cadcb9feb
# 4
# 8
# 12
# 1390696b70b6
# 4
# 8
# 12
# 13cad6eeabe8
# 4
# 8
# 12
# 151c7f2d4183
# 4
# 8
# 12
# 154ee2b6d27a
# 4
# 8
# 12
# 169f5f6d8c9d
# 4
# 8
# 12
# 16f0ec26d608
# 4
# 8
# 12
# 189a2a32a615
# 4
# 8
# 12
# 1952e5f91de0
# 4
# 8
# 12
# 1a17a1bd648b
# 4
# 8
# 12
# 1aba91a601c6
# 4
# 8
# 12
# 1adaeb44f109
# 4
# 8
# 12
# 1ae8a68a40e4
# 4
# 8
# 12
# 1b25ea8ba94d
# 4
# ...
