# %%
import numpy as np
import pandas as pd
import os as os
import cv2
import shutil

# %%
for files in os.listdir('./testTrialLand'):
    path = "./testTrialLand/" + files
    print(path)
    try:  
        os.mkdir(path)
    except OSError:  
        print ("Creation of the directory %s failed" % path)
    else:  
        print ("Successfully created the directory %s " % path)

# %%
for files in os.listdir('./train'):
    path = "./testMain/" + files
    print(path)
    try:  
        os.mkdir(path)
    except OSError:  
        print ("Creation of the directory %s failed" % path)
    else:  
        print ("Successfully created the directory %s " % path)
# Out:
# ./testMain/00087a6bd4dc
# Successfully created the directory ./testMain/00087a6bd4dc
# ./testMain/02159e548029
# Successfully created the directory ./testMain/02159e548029
# ./testMain/03a857ce842d
# Successfully created the directory ./testMain/03a857ce842d
# ./testMain/0495dcf27283
# Successfully created the directory ./testMain/0495dcf27283
# ./testMain/04bd942b463b
# Successfully created the directory ./testMain/04bd942b463b
# ./testMain/0789bed99cb8
# Successfully created the directory ./testMain/0789bed99cb8
# ./testMain/0795e132d090
# Successfully created the directory ./testMain/0795e132d090
# ./testMain/08a646be6b30
# Successfully created the directory ./testMain/08a646be6b30
# ./testMain/0cdf5b5d0ce1
# Successfully created the directory ./testMain/0cdf5b5d0ce1
# ./testMain/0ce66b539f52
# Successfully created the directory ./testMain/0ce66b539f52
# ./testMain/0d1a9caf4350
# Successfully created the directory ./testMain/0d1a9caf4350
# ./testMain/0d3adbbc9a8b
# Successfully created the directory ./testMain/0d3adbbc9a8b
# ./testMain/0d53224da2b7
# Successfully created the directory ./testMain/0d53224da2b7
# ./testMain/0de66245f268
# Successfully created the directory ./testMain/0de66245f268
# ./testMain/0ed6904e1004
# Successfully created the directory ./testMain/0ed6904e1004
# ./testMain/0ee135a3cccc
# Successfully created the directory ./testMain/0ee135a3cccc
# ./testMain/0eeaf1ff136d
# Successfully created the directory ./testMain/0eeaf1ff136d
# ./testMain/11acc40dc0ea
# Successfully created the directory ./testMain/11acc40dc0ea
# ./testMain/11f3dc041cfb
# Successfully created the directory ./testMain/11f3dc041cfb
# ./testMain/11fcda0a9e1c
# Successfully created the directory ./testMain/11fcda0a9e1c
# ./testMain/120c1dc7b116
# Successfully created the directory ./testMain/120c1dc7b116
# ./testMain/1258cf954183
# Successfully created the directory ./testMain/1258cf954183
# ./testMain/125cadcb9feb
# Successfully created the directory ./testMain/125cadcb9feb
# ./testMain/1390696b70b6
# Successfully created the directory ./testMain/1390696b70b6
# ./testMain/13cad6eeabe8
# Successfully created the directory ./testMain/13cad6eeabe8
# ./testMain/151c7f2d4183
# Successfully created the directory ./testMain/151c7f2d4183
# ./testMain/154ee2b6d27a
# Successfully created the directory ./testMain/154ee2b6d27a
# ./testMain/169f5f6d8c9d
# Successfully created the directory ./testMain/169f5f6d8c9d
# ./testMain/16f0ec26d608
# Successfully created the directory ./testMain/16f0ec26d608
# ./testMain/189a2a32a615
# Successfully created the directory ./testMain/189a2a32a615
# ./testMain/1952e5f91de0
# Successfully created the directory ./testMain/1952e5f91de0
# ./testMain/1a17a1bd648b
# Successfully created the directory ./testMain/1a17a1bd648b
# ./testMain/1aba91a601c6
# Successfully created the directory ./testMain/1aba91a601c6
# ./testMain/1adaeb44f109
# Successfully created the directory ./testMain/1adaeb44f109
# ./testMain/1ae8a68a40e4
# Successfully created the directory ./testMain/1ae8a68a40e4
# ./testMain/1b25ea8ba94d
# Successfully created the directory ./testMain/1b25ea8ba94d
# ./testMain/1ba84b81628e
# Successfully created the directory ./testMain/1ba84b81628e
# ./testMain/1c5748340af8
# Successfully created the directory ./testMain/1c5748340af8
# ./testMain/1e6f48393e17
# Successfully created the directory ./testMain/1e6f48393e17
# ./testMain/1e89e1af42e7
# Successfully created the directory ./testMain/1e89e1af42e7
# ./testMain/21a7e6726ee3
# Successfully created the directory ./testMain/21a7e6726ee3
# ./testMain/2267f4aa0d2c
# Successfully created the directory ./testMain/2267f4aa0d2c
# ./testMain/2335eef27de6
# Successfully created the directory ./testMain/2335eef27de6
# ./testMain/23c088f6ec27
# Successfully created the directory ./testMain/23c088f6ec27
# ./testMain/245f9c9eab8a
# Successfully created the directory ./testMain/245f9c9eab8a
# ./testMain/26ccab021981
# Successfully created the directory ./testMain/26ccab021981
# ./testMain/28109f18d9d4
# Successfully created the directory ./testMain/28109f18d9d4
# ./testMain/28d7fb5ba432
# Successfully created the directory ./testMain/28d7fb5ba432
# ./testMain/28d9a149cb02
# Successfully created the directory ./testMain/28d9a149cb02
# ./testMain/292f59c6a347
# Successfully created the directory ./testMain/292f59c6a347
# ./testMain/293a0fa72e5b
# Successfully created the directory ./testMain/293a0fa72e5b
# ./testMain/2990f858e939
# Successfully created the directory ./testMain/2990f858e939
# ./testMain/2a4a8964ebf3
# Successfully created the directory ./testMain/2a4a8964ebf3
# ./testMain/2af7c265531e
# Successfully created the directory ./testMain/2af7c265531e
# ./testMain/2c57132da7a0
# Successfully created the directory ./testMain/2c57132da7a0
# ./testMain/2cb06c1f5bb1
# Successfully created the directory ./testMain/2cb06c1f5bb1
# ./testMain/2cb91c2543fa
# Successfully created the directory ./testMain/2cb91c2543fa
# ./testMain/2ea62c1beee7
# Successfully created the directory ./testMain/2ea62c1beee7
# ./testMain/2f39abb12388
# Successfully created the directory ./testMain/2f39abb12388
# ./testMain/2faf504842df
# Successfully created the directory ./testMain/2faf504842df
# ./testMain/304437bad7ff
# Successfully created the directory ./testMain/304437bad7ff
# ./testMain/3071362591f7
# Successfully created the directory ./testMain/3071362591f7
# ./testMain/31186febd775
# Successfully created the directory ./testMain/31186febd775
# ./testMain/316bbfd3d93d
# Successfully created the directory ./testMain/316bbfd3d93d
# ./testMain/32edfb7723ff
# Successfully created the directory ./testMain/32edfb7723ff
# ./testMain/32ff007d9505
# Successfully created the directory ./testMain/32ff007d9505
# ./testMain/33a310ea7462
# Successfully created the directory ./testMain/33a310ea7462
# ./testMain/344ece157efc
# Successfully created the directory ./testMain/344ece157efc
# ./testMain/34b0c08544a5
# Successfully created the directory ./testMain/34b0c08544a5
# ./testMain/34defeec3ce6
# Successfully created the directory ./testMain/34defeec3ce6
# ./testMain/351c583eabd6
# Successfully created the directory ./testMain/351c583eabd6
# ./testMain/3627b6f4c16d
# Successfully created the directory ./testMain/3627b6f4c16d
# ./testMain/364923a5002f
# Successfully created the directory ./testMain/364923a5002f
# ./testMain/364fd5fd7569
# Successfully created the directory ./testMain/364fd5fd7569
# ./testMain/36a3f7f77e85
# Successfully created the directory ./testMain/36a3f7f77e85
# ./testMain/371f057d1242
# Successfully created the directory ./testMain/371f057d1242
# ./testMain/3789e15178c7
# Successfully created the directory ./testMain/3789e15178c7
# ./testMain/3810c5e1cdeb
# Successfully created the directory ./testMain/3810c5e1cdeb
# ./testMain/3a7a8f03e713
# Successfully created the directory ./testMain/3a7a8f03e713
# ./testMain/3afec4b5ac07
# Successfully created the directory ./testMain/3afec4b5ac07
# ./testMain/3b45f83ba3fa
# Successfully created the directory ./testMain/3b45f83ba3fa
# ./testMain/3bca821c8c41
# Successfully created the directory ./testMain/3bca821c8c41
# ./testMain/3c16409ab9db
# Successfully created the directory ./testMain/3c16409ab9db
# ./testMain/3c54e71fd2c9
# Successfully created the directory ./testMain/3c54e71fd2c9
# ./testMain/3c6acfceb552
# Successfully created the directory ./testMain/3c6acfceb552
# ./testMain/3cb21125f126
# Successfully created the directory ./testMain/3cb21125f126
# ./testMain/3d7a1030deeb
# Successfully created the directory ./testMain/3d7a1030deeb
# ./testMain/3f202616a2b9
# Successfully created the directory ./testMain/3f202616a2b9
# ./testMain/3f3e362dea23
# Successfully created the directory ./testMain/3f3e362dea23
# ./testMain/3f8d611822bc
# Successfully created the directory ./testMain/3f8d611822bc
# ./testMain/40851e617b93
# Successfully created the directory ./testMain/40851e617b93
# ./testMain/419687d50dcd
# Successfully created the directory ./testMain/419687d50dcd
# ./testMain/42415ff65013
# Successfully created the directory ./testMain/42415ff65013
# ./testMain/424658d9f222
# Successfully created the directory ./testMain/424658d9f222
# ./testMain/42a3297ccd4b
# Successfully created the directory ./testMain/42a3297ccd4b
# ./testMain/42b3feca1993
# Successfully created the directory ./testMain/42b3feca1993
# ./testMain/42d81612e2ce
# Successfully created the directory ./testMain/42d81612e2ce
# ./testMain/430f0cb5666c
# Successfully created the directory ./testMain/430f0cb5666c
# ./testMain/47ea8f25c948
# Successfully created the directory ./testMain/47ea8f25c948
# ./testMain/4856fcb85be0
# Successfully created the directory ./testMain/4856fcb85be0
# ./testMain/48b3f0c936b5
# Successfully created the directory ./testMain/48b3f0c936b5
# ./testMain/4a4364d7fc6d
# Successfully created the directory ./testMain/4a4364d7fc6d
# ./testMain/4b74275babf7
# Successfully created the directory ./testMain/4b74275babf7
# ./testMain/4baf50a3d8c2
# Successfully created the directory ./testMain/4baf50a3d8c2
# ./testMain/4bea0766c14c
# Successfully created the directory ./testMain/4bea0766c14c
# ./testMain/4dc8a7fe7c02
# Successfully created the directory ./testMain/4dc8a7fe7c02
# ./testMain/4df1536de792
# Successfully created the directory ./testMain/4df1536de792
# ./testMain/4e308ad8a254
# Successfully created the directory ./testMain/4e308ad8a254
# ./testMain/4e5ac4b9f074
# Successfully created the directory ./testMain/4e5ac4b9f074
# ./testMain/4e7bc95552ed
# Successfully created the directory ./testMain/4e7bc95552ed
# ./testMain/4f0397cf7937
# Successfully created the directory ./testMain/4f0397cf7937
# ./testMain/4f1f065d78ac
# Successfully created the directory ./testMain/4f1f065d78ac
# ./testMain/4fc2470c0f7b
# Successfully created the directory ./testMain/4fc2470c0f7b
# ./testMain/51f1cdf5f539
# Successfully created the directory ./testMain/51f1cdf5f539
# ./testMain/528eb34a4c29
# Successfully created the directory ./testMain/528eb34a4c29
# ./testMain/54ee69d7d5e5
# Successfully created the directory ./testMain/54ee69d7d5e5
# ./testMain/553c658b9efa
# Successfully created the directory ./testMain/553c658b9efa
# ./testMain/5588758ee21c
# Successfully created the directory ./testMain/5588758ee21c
# ./testMain/56023a17481b
# Successfully created the directory ./testMain/56023a17481b
# ./testMain/562706000bd7
# Successfully created the directory ./testMain/562706000bd7
# ./testMain/5a194c1384f3
# Successfully created the directory ./testMain/5a194c1384f3
# ./testMain/5ab34f0e3ea5
# Successfully created the directory ./testMain/5ab34f0e3ea5
# ./testMain/5bc30efeb7bf
# Successfully created the directory ./testMain/5bc30efeb7bf
# ./testMain/5bcde75955bb
# Successfully created the directory ./testMain/5bcde75955bb
# ./testMain/5d95d80e10a9
# Successfully created the directory ./testMain/5d95d80e10a9
# ./testMain/5df60cf7cab2
# Successfully created the directory ./testMain/5df60cf7cab2
# ./testMain/5fb012d30fd9
# Successfully created the directory ./testMain/5fb012d30fd9
# ./testMain/61060ada97c9
# Successfully created the directory ./testMain/61060ada97c9
# ./testMain/6131a03dd028
# Successfully created the directory ./testMain/6131a03dd028
# ./testMain/630335e37f40
# Successfully created the directory ./testMain/630335e37f40
# ./testMain/6343156803f9
# Successfully created the directory ./testMain/6343156803f9
# ./testMain/64f701f36437
# Successfully created the directory ./testMain/64f701f36437
# ./testMain/65051cfe0789
# Successfully created the directory ./testMain/65051cfe0789
# ./testMain/66fea07e1152
# Successfully created the directory ./testMain/66fea07e1152
# ./testMain/6752de44b721
# Successfully created the directory ./testMain/6752de44b721
# ./testMain/683ddec95b82
# Successfully created the directory ./testMain/683ddec95b82
# ./testMain/68fcee2be01f
# Successfully created the directory ./testMain/68fcee2be01f
# ./testMain/695f39dfac16
# Successfully created the directory ./testMain/695f39dfac16
# ./testMain/69915dab0755
# Successfully created the directory ./testMain/69915dab0755
# ./testMain/69fba9e8f572
# Successfully created the directory ./testMain/69fba9e8f572
# ./testMain/6a951d3a3131
# Successfully created the directory ./testMain/6a951d3a3131
# ./testMain/6ae670e86620
# Successfully created the directory ./testMain/6ae670e86620
# ./testMain/6ba36af67cb0
# Successfully created the directory ./testMain/6ba36af67cb0
# ./testMain/6bf969856536
# Successfully created the directory ./testMain/6bf969856536
# ./testMain/6bfd601be25e
# Successfully created the directory ./testMain/6bfd601be25e
# ./testMain/6bff9e10288e
# Successfully created the directory ./testMain/6bff9e10288e
# ./testMain/6c0cd487abcd
# Successfully created the directory ./testMain/6c0cd487abcd
# ./testMain/6c3470c34408
# Successfully created the directory ./testMain/6c3470c34408
# ./testMain/6cc98271f4dd
# Successfully created the directory ./testMain/6cc98271f4dd
# ./testMain/6d21aad248e4
# Successfully created the directory ./testMain/6d21aad248e4
# ./testMain/6d375bc2ece1
# Successfully created the directory ./testMain/6d375bc2ece1
# ./testMain/6d77433cc7ce
# Successfully created the directory ./testMain/6d77433cc7ce
# ./testMain/6dc8783eca68
# Successfully created the directory ./testMain/6dc8783eca68
# ./testMain/6e016b8b3617
# Successfully created the directory ./testMain/6e016b8b3617
# ./testMain/6f6dced498c4
# Successfully created the directory ./testMain/6f6dced498c4
# ./testMain/70b6a79565fe
# Successfully created the directory ./testMain/70b6a79565fe
# ./testMain/717689f3e788
# Successfully created the directory ./testMain/717689f3e788
# ./testMain/7251c8797749
# Successfully created the directory ./testMain/7251c8797749
# ./testMain/768f299c36e1
# Successfully created the directory ./testMain/768f299c36e1
# ./testMain/781c5338fe02
# Successfully created the directory ./testMain/781c5338fe02
# ./testMain/784ca55262c2
# Successfully created the directory ./testMain/784ca55262c2
# ./testMain/78bfb9c780db
# Successfully created the directory ./testMain/78bfb9c780db
# ./testMain/78f63d808555
# Successfully created the directory ./testMain/78f63d808555
# ./testMain/791c1a9775be
# Successfully created the directory ./testMain/791c1a9775be
# ./testMain/795d2ee07ce2
# Successfully created the directory ./testMain/795d2ee07ce2
# ./testMain/79a7691a90b1
# Successfully created the directory ./testMain/79a7691a90b1
# ./testMain/7ab9747cf6d7
# Successfully created the directory ./testMain/7ab9747cf6d7
# ./testMain/7abaa38c227f
# Successfully created the directory ./testMain/7abaa38c227f
# ./testMain/7ac210ba75a1
# Successfully created the directory ./testMain/7ac210ba75a1
# ./testMain/7bd1142155ae
# Successfully created the directory ./testMain/7bd1142155ae
# ./testMain/7fbc761387f3
# Successfully created the directory ./testMain/7fbc761387f3
# ./testMain/82f72273d23e
# Successfully created the directory ./testMain/82f72273d23e
# ./testMain/843763f47895
# Successfully created the directory ./testMain/843763f47895
# ./testMain/858841907a4a
# Successfully created the directory ./testMain/858841907a4a
# ./testMain/85bc655a7523
# Successfully created the directory ./testMain/85bc655a7523
# ./testMain/85cba1a00135
# Successfully created the directory ./testMain/85cba1a00135
# ./testMain/8603668953a6
# Successfully created the directory ./testMain/8603668953a6
# ./testMain/86c10c8c6206
# Successfully created the directory ./testMain/86c10c8c6206
# ./testMain/878738468f6b
# Successfully created the directory ./testMain/878738468f6b
# ./testMain/87e334269396
# Successfully created the directory ./testMain/87e334269396
# ./testMain/880ab8468df2
# Successfully created the directory ./testMain/880ab8468df2
# ./testMain/880fec285c06
# Successfully created the directory ./testMain/880fec285c06
# ./testMain/888e04d96663
# Successfully created the directory ./testMain/888e04d96663
# ./testMain/88bc32b9e1d9
# Successfully created the directory ./testMain/88bc32b9e1d9
# ./testMain/898339fab87a
# Successfully created the directory ./testMain/898339fab87a
# ./testMain/8b4b87ad7be6
# Successfully created the directory ./testMain/8b4b87ad7be6
# ./testMain/8b88fb784951
# Successfully created the directory ./testMain/8b88fb784951
# ./testMain/8d1a6723c458
# Successfully created the directory ./testMain/8d1a6723c458
# ./testMain/8d5423cb763c
# Successfully created the directory ./testMain/8d5423cb763c
# ./testMain/8d78483ce302
# Successfully created the directory ./testMain/8d78483ce302
# ./testMain/90b65c521a8b
# Successfully created the directory ./testMain/90b65c521a8b
# ./testMain/90fdd8932877
# Successfully created the directory ./testMain/90fdd8932877
# ./testMain/917f262f1608
# Successfully created the directory ./testMain/917f262f1608
# ./testMain/9274d0b3caa8
# Successfully created the directory ./testMain/9274d0b3caa8
# ./testMain/93881caf9f70
# Successfully created the directory ./testMain/93881caf9f70
# ./testMain/98ee0624de87
# Successfully created the directory ./testMain/98ee0624de87
# ./testMain/99639c826ea5
# Successfully created the directory ./testMain/99639c826ea5
# ./testMain/9a2bfb24ba6e
# Successfully created the directory ./testMain/9a2bfb24ba6e
# ./testMain/9ab2a45de8c7
# Successfully created the directory ./testMain/9ab2a45de8c7
# ./testMain/9c2e82c23803
# Successfully created the directory ./testMain/9c2e82c23803
# ./testMain/9cc257b449d0
# Successfully created the directory ./testMain/9cc257b449d0
# ./testMain/9d8c465a0881
# Successfully created the directory ./testMain/9d8c465a0881
# ./testMain/9dfaeb835626
# Successfully created the directory ./testMain/9dfaeb835626
# ./testMain/a070dbb32d2b
# Successfully created the directory ./testMain/a070dbb32d2b
# ./testMain/a078586ccdee
# Successfully created the directory ./testMain/a078586ccdee
# ./testMain/a1038b207299
# Successfully created the directory ./testMain/a1038b207299
# ./testMain/a2df64508b97
# Successfully created the directory ./testMain/a2df64508b97
# ./testMain/a3e2e104d58a
# Successfully created the directory ./testMain/a3e2e104d58a
# ./testMain/a4551c5409e3
# Successfully created the directory ./testMain/a4551c5409e3
# ./testMain/a46baa0b3ac0
# Successfully created the directory ./testMain/a46baa0b3ac0
# ./testMain/a56f923399ca
# Successfully created the directory ./testMain/a56f923399ca
# ./testMain/a5fea424990e
# Successfully created the directory ./testMain/a5fea424990e
# ./testMain/a7b9e343cf6b
# Successfully created the directory ./testMain/a7b9e343cf6b
# ./testMain/a7c1ef8d9cc9
# Successfully created the directory ./testMain/a7c1ef8d9cc9
# ./testMain/acb0fd30b83d
# Successfully created the directory ./testMain/acb0fd30b83d
# ./testMain/ad5a6a058944
# Successfully created the directory ./testMain/ad5a6a058944
# ./testMain/ae296a20fdd9
# Successfully created the directory ./testMain/ae296a20fdd9
# ./testMain/b1a27da4f01c
# Successfully created the directory ./testMain/b1a27da4f01c
# ./testMain/b24fd9084449
# Successfully created the directory ./testMain/b24fd9084449
# ./testMain/b38c4e132183
# Successfully created the directory ./testMain/b38c4e132183
# ./testMain/b44091aa62e4
# Successfully created the directory ./testMain/b44091aa62e4
# ./testMain/b58cc561e560
# Successfully created the directory ./testMain/b58cc561e560
# ./testMain/b63a6f7952d4
# Successfully created the directory ./testMain/b63a6f7952d4
# ./testMain/b98c63cd6102
# Successfully created the directory ./testMain/b98c63cd6102
# ./testMain/ba7e7421003b
# Successfully created the directory ./testMain/ba7e7421003b
# ./testMain/bad53871c7d9
# Successfully created the directory ./testMain/bad53871c7d9
# ./testMain/bb2f95262773
# Successfully created the directory ./testMain/bb2f95262773
# ./testMain/bb7625a3f1d4
# Successfully created the directory ./testMain/bb7625a3f1d4
# ./testMain/bd8d5780ed04
# Successfully created the directory ./testMain/bd8d5780ed04
# ./testMain/be86e79f1225
# Successfully created the directory ./testMain/be86e79f1225
# ./testMain/bec93f7ddb19
# Successfully created the directory ./testMain/bec93f7ddb19
# ./testMain/bf92e198d9b6
# Successfully created the directory ./testMain/bf92e198d9b6
# ./testMain/bf9932f7aca8
# Successfully created the directory ./testMain/bf9932f7aca8
# ./testMain/bf9a32258ef4
# Successfully created the directory ./testMain/bf9a32258ef4
# ./testMain/c24b8293eceb
# Successfully created the directory ./testMain/c24b8293eceb
# ./testMain/c2fd64144e97
# Successfully created the directory ./testMain/c2fd64144e97
# ./testMain/c353e364e931
# Successfully created the directory ./testMain/c353e364e931
# ./testMain/c3614abc7405
# Successfully created the directory ./testMain/c3614abc7405
# ./testMain/c3dafdb02e7f
# Successfully created the directory ./testMain/c3dafdb02e7f
# ./testMain/c4ac16c0dd59
# Successfully created the directory ./testMain/c4ac16c0dd59
# ./testMain/c4f1840b2a65
# Successfully created the directory ./testMain/c4f1840b2a65
# ./testMain/c502287be9f6
# Successfully created the directory ./testMain/c502287be9f6
# ./testMain/c52b272a5329
# Successfully created the directory ./testMain/c52b272a5329
# ./testMain/c53e374fdd72
# Successfully created the directory ./testMain/c53e374fdd72
# ./testMain/c6f50d44f141
# Successfully created the directory ./testMain/c6f50d44f141
# ./testMain/c7145a80089e
# Successfully created the directory ./testMain/c7145a80089e
# ./testMain/c7a94c46a3b2
# Successfully created the directory ./testMain/c7a94c46a3b2
# ./testMain/c87688f6960e
# Successfully created the directory ./testMain/c87688f6960e
# ./testMain/c8d52e0ba341
# Successfully created the directory ./testMain/c8d52e0ba341
# ./testMain/c9acf5847ef1
# Successfully created the directory ./testMain/c9acf5847ef1
# ./testMain/c9f382c7349e
# Successfully created the directory ./testMain/c9f382c7349e
# ./testMain/cafee4122080
# Successfully created the directory ./testMain/cafee4122080
# ./testMain/cd2e588ef1c5
# Successfully created the directory ./testMain/cd2e588ef1c5
# ./testMain/ce74dfdf123b
# Successfully created the directory ./testMain/ce74dfdf123b
# ./testMain/cf5add31c130
# Successfully created the directory ./testMain/cf5add31c130
# ./testMain/cf65b1c5e147
# Successfully created the directory ./testMain/cf65b1c5e147
# ./testMain/cf89c3220bc4
# Successfully created the directory ./testMain/cf89c3220bc4
# ./testMain/d0392fd5feb6
# Successfully created the directory ./testMain/d0392fd5feb6
# ./testMain/d0dab700c896
# Successfully created the directory ./testMain/d0dab700c896
# ./testMain/d1a3af34e674
# Successfully created the directory ./testMain/d1a3af34e674
# ./testMain/d22e6a2ca6df
# Successfully created the directory ./testMain/d22e6a2ca6df
# ./testMain/d326cb5c3d12
# Successfully created the directory ./testMain/d326cb5c3d12
# ./testMain/d3d0d2662918
# Successfully created the directory ./testMain/d3d0d2662918
# ./testMain/d46244bc42ed
# Successfully created the directory ./testMain/d46244bc42ed
# ./testMain/d61b6bfeabb2
# Successfully created the directory ./testMain/d61b6bfeabb2
# ./testMain/d8216041ffa9
# Successfully created the directory ./testMain/d8216041ffa9
# ./testMain/d8e1c401ac3c
# Successfully created the directory ./testMain/d8e1c401ac3c
# ./testMain/d8f11603ef08
# Successfully created the directory ./testMain/d8f11603ef08
# ./testMain/d9b2ded58b72
# Successfully created the directory ./testMain/d9b2ded58b72
# ./testMain/db09fec614d2
# Successfully created the directory ./testMain/db09fec614d2
# ./testMain/dc1c5c2b9e49
# Successfully created the directory ./testMain/dc1c5c2b9e49
# ./testMain/dc995bf5296a
# Successfully created the directory ./testMain/dc995bf5296a
# ./testMain/dd47eb7ac4ee
# Successfully created the directory ./testMain/dd47eb7ac4ee
# ./testMain/dd70a0a51e3b
# Successfully created the directory ./testMain/dd70a0a51e3b
# ./testMain/ddb513df9406
# Successfully created the directory ./testMain/ddb513df9406
# ./testMain/de3ca5ec1e59
# Successfully created the directory ./testMain/de3ca5ec1e59
# ./testMain/de74550a306a
# Successfully created the directory ./testMain/de74550a306a
# ./testMain/df642435a951
# Successfully created the directory ./testMain/df642435a951
# ./testMain/e05b96cc2b0d
# Successfully created the directory ./testMain/e05b96cc2b0d
# ./testMain/e114fcbb9723
# Successfully created the directory ./testMain/e114fcbb9723
# ./testMain/e1d2c25f3510
# Successfully created the directory ./testMain/e1d2c25f3510
# ./testMain/e2230d0ceb02
# Successfully created the directory ./testMain/e2230d0ceb02
# ./testMain/e597d76a0c33
# Successfully created the directory ./testMain/e597d76a0c33
# ./testMain/e5fc2c1c4a8b
# Successfully created the directory ./testMain/e5fc2c1c4a8b
# ./testMain/e6892bf10d31
# Successfully created the directory ./testMain/e6892bf10d31
# ./testMain/e8f607100c1f
# Successfully created the directory ./testMain/e8f607100c1f
# ./testMain/eaf9eb0b2293
# Successfully created the directory ./testMain/eaf9eb0b2293
# ./testMain/eb07e3f63ad2
# Successfully created the directory ./testMain/eb07e3f63ad2
# ./testMain/eb91b1c659a0
# Successfully created the directory ./testMain/eb91b1c659a0
# ./testMain/ebfdf6ec7ede
# Successfully created the directory ./testMain/ebfdf6ec7ede
# ./testMain/ed13cbcdd5d8
# Successfully created the directory ./testMain/ed13cbcdd5d8
# ./testMain/ed8472086df8
# Successfully created the directory ./testMain/ed8472086df8
# ./testMain/eeb7eeca738e
# Successfully created the directory ./testMain/eeb7eeca738e
# ./testMain/eefc0d8c94f0
# Successfully created the directory ./testMain/eefc0d8c94f0
# ./testMain/ef5567efd904
# Successfully created the directory ./testMain/ef5567efd904
# ./testMain/efaef69e148d
# Successfully created the directory ./testMain/efaef69e148d
# ./testMain/f00905abd3d7
# Successfully created the directory ./testMain/f00905abd3d7
# ./testMain/f1eb080c7182
# Successfully created the directory ./testMain/f1eb080c7182
# ./testMain/f3b482e091c0
# Successfully created the directory ./testMain/f3b482e091c0
# ./testMain/f3eee6348205
# Successfully created the directory ./testMain/f3eee6348205
# ./testMain/f4cd1286d5f4
# Successfully created the directory ./testMain/f4cd1286d5f4
# ./testMain/f591b4f2e006
# Successfully created the directory ./testMain/f591b4f2e006
# ./testMain/f70052627830
# Successfully created the directory ./testMain/f70052627830
# ./testMain/f707d6fbc0cd
# Successfully created the directory ./testMain/f707d6fbc0cd
# ./testMain/f7ad86e13ed7
# Successfully created the directory ./testMain/f7ad86e13ed7
# ./testMain/f8b6f4c39204
# Successfully created the directory ./testMain/f8b6f4c39204
# ./testMain/f98dbe8a5ee2
# Successfully created the directory ./testMain/f98dbe8a5ee2
# ./testMain/fa006be8b6d9
# Successfully created the directory ./testMain/fa006be8b6d9
# ./testMain/fa613ac8eac5
# Successfully created the directory ./testMain/fa613ac8eac5
# ./testMain/fb1b923dd978
# Successfully created the directory ./testMain/fb1b923dd978
# ./testMain/fc237174b128
# Successfully created the directory ./testMain/fc237174b128
# ./testMain/fc5f1a3a66cf
# Successfully created the directory ./testMain/fc5f1a3a66cf
# ./testMain/fce0ba5b8ed7
# Successfully created the directory ./testMain/fce0ba5b8ed7
# ./testMain/fd9da5d0bb6f
# Successfully created the directory ./testMain/fd9da5d0bb6f
# ./testMain/fdc2c87853ce
# Successfully created the directory ./testMain/fdc2c87853ce
# ./testMain/feaf59172a01
# Successfully created the directory ./testMain/feaf59172a01
# ./testMain/fecea3036c59
# Successfully created the directory ./testMain/fecea3036c59
# ./testMain/fff9b3a5373f
# Successfully created the directory ./testMain/fff9b3a5373f
